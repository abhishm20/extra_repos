# %%
from StringIO import StringIO
import requests
r = requests.get('https://docs.google.com/spreadsheets/d/1hhhBAKK7kCF20b_bygidlA4xBws5Jl4wi3yOw5tATeg/export?format=xlsx')
data = r.content

# %%
data
# Out:
# 'PK\x03\x04\x14\x00\x08\x08\x08\x00O\xb6~J\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x18\x00\x00\x00xl/drawings/drawing1.xml\x9d\xd0AN\xc30\x10\x05\xd0\x13p\x87h\xf6\xad\x03\x0b\x84\xa2\xa6\xddD\x9c\x00\x0e0\xd8\x93\xd8\xc2c[3.mo\x8fE\xc9\xbe\xca\xf2\xebk\x9e\xbe\xe6p\xbar\xec~H4\xe44\xc2\xf3\xbe\x87\x8e\x92\xcd.\xa4e\x84\xcf\x8f\xf7\xdd\x1btZ19\x8c9\xd1\x087R8\x1d\x9f\x0eW\'\xc3E\'\xe9\xda}\xd2\xa1\xc5\x11|\xade0F\xad\'F\xdd\xe7B\xa9\xb5s\x16\xc6\xda\xa2,\xc6\t^\x9a\xcc\xd1\xbc\xf4\xfd\xab\xd1"\x84N=Q\x9d\xee\r\xfc{\xb8Ac\x0ci\xbd\x7fhM\x9e\xe7`i\xca\xf6\xcc\x94\xea\x1d\x11\x8aX\xdb/\xd4\x87\xa2\xabf7\xac\xb1\x1e\xa5\xae\x00?$0\xca\xf7\xb9\xecl\xe6\xd26|\x85\x18\xea\xed\x0f[\x19\xb7\xf0\x86%.\xe0"\xc8`\x8e\xbfPK\x07\x08\x1f\x9a`(\xcc\x00\x00\x00\xee\x01\x00\x00PK\x03\x04\x14\x00\x08\x08\x08\x00O\xb6~J\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x18\x00\x00\x00xl/drawings/drawing2.xml\x9d\xd0AN\xc30\x10\x05\xd0\x13p\x87h\xf6\xad\x03\x0b\x84\xa2\xa6\xddD\x9c\x00\x0e0\xd8\x93
# ...

# %%
import pandas

# %%
xls = pandas.ExcelFile(StringIO(data))

# %%
k = xls.parse('kitchen')

# %%
k
# Out:
#                                     key  \
# 0                              app_name
# 1                            start_date
# 2                              end_date
# 3                              settings
# 4                               reports
# 5                           closeDrawer
# 6                            openDrawer
# 7                           get_started
# 8                                  view
# 9                  automatic_allocation
# 10                           edit_order
# 11                                 edit
# 12                           select_tax
# 13                     profile_settings
# 14                        selling_items
# 15                             features
# 16               approval_order_message
# 17                           restaurant
# 18                        show_tutorial
# 19                        set_suppliers
# 20               set_automatic_ordering
# 21                        risk_purchase
# ...
